# %%
# Create a new virtual environment
# !python -m venv myenv

# %%
# !myenv\Scripts\activate

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\jtaiwo\anaconda3\lib\site-packages (1.37.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (5.27.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\jtaiwo\appdata\roaming\python\python39\site-packages (from streamlit) (1.24.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.16.0)
# Requirement already satisfied: narwhals>=1.1.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.4.2)
# Requirement already satisfied: jinja2 in c:\users\jtaiwo\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (2.11.3)
# Requirement already satisfied: colorama in c:\users\jtaiwo\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jtaiwo\anaconda3\lib\site-packages (from packaging<25,>=20->streamlit) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2022.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jtaiwo\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\jtaiwo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gspread
# Out:
# Collecting gspreadNote: you may need to restart the kernel to use updated packages.
#
#   Downloading gspread-6.1.2-py3-none-any.whl (57 kB)
#      -------------------------------------- 57.5/57.5 kB 112.0 kB/s eta 0:00:00
# Collecting google-auth-oauthlib>=0.4.1
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Collecting google-auth>=1.12.0
#   Downloading google_auth-2.33.0-py2.py3-none-any.whl (200 kB)
#      ------------------------------------ 200.5/200.5 kB 392.4 kB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jtaiwo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jtaiwo\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2022.9.14)
# Installing collected packages: rsa, oauthlib, requests-oauthlib, google-auth, google-auth-oauthlib, gspread
# Successfully installed google-auth-2.33.0 google-auth-oauthlib-1.2.1 gspread-6.1.2 oauthlib-3.2.2 requests-oauthlib-2.0.0 rsa-4.9

# %%
pip install oauth2client
# Out:
# Collecting oauth2clientNote: you may need to restart the kernel to use updated packages.
#
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      -------------------------------------- 98.2/98.2 kB 165.7 kB/s eta 0:00:00
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\jtaiwo\anaconda3\lib\site-packages (from oauth2client) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\jtaiwo\anaconda3\lib\site-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from oauth2client) (1.16.0)
# Collecting httplib2>=0.9.1
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      -------------------------------------- 96.9/96.9 kB 618.7 kB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\jtaiwo\anaconda3\lib\site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\jtaiwo\anaconda3\lib\site-packages (from httplib2>=0.9.1->oauth2client) (3.0.9)
# Installing collected packages: httplib2, oauth2client
# Successfully installed httplib2-0.22.0 oauth2client-4.1.3

# %%
pip install pandas xlsxwriter
# Out:
# Requirement already satisfied: pandas in c:\users\jtaiwo\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: xlsxwriter in c:\users\jtaiwo\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jtaiwo\appdata\roaming\python\python39\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jtaiwo\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\jtaiwo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import time
import random
import pandas as pd
from io import BytesIO

# Function to authenticate and connect to Google Sheets
def connect_to_sheets():
    scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
    creds = ServiceAccountCredentials.from_json_keyfile_name("service_cred.json", scope)
    client = gspread.authorize(creds)
    return client

# Function to generate a unique Repair ID
def generate_repair_id():
    timestamp = int(time.time())
    random_number = random.randint(1000, 9999)
    return f"R{timestamp}{random_number}"

# Function to submit the repair record
def submit_repair_record(asset_id, repair_date, technician_name, diagnosis_report, recommended_solutions, repair_actions_taken, notes):
    client = connect_to_sheets()
    spreadsheet = client.open_by_key("1vPT_3GSVaM3AIcpsL6sTfgl_GyoNRnqAwaswzTzY6h8")
    repair_records_sheet = spreadsheet.worksheet("Repair Records")
    
    # Generate a unique Repair ID
    repair_id = generate_repair_id()
    
    # Get asset details from Asset Information sheet
    asset_info_sheet = spreadsheet.worksheet("Asset Information")
    asset_row = asset_info_sheet.find(asset_id).row
    asset_details = asset_info_sheet.row_values(asset_row)[1:]  # Exclude Asset ID
    
    # Append the new repair record
    repair_records_sheet.append_row([
        repair_id, asset_id, *asset_details, repair_date, technician_name, diagnosis_report, 
        recommended_solutions, repair_actions_taken, notes
    ])
    
    # Update the Asset Information sheet
    update_asset_info(asset_id)
    st.success(f"Repair record submitted with Repair ID: {repair_id} and asset information updated.")

def update_asset_info(asset_id):
    client = connect_to_sheets()
    spreadsheet = client.open_by_key("1vPT_3GSVaM3AIcpsL6sTfgl_GyoNRnqAwaswzTzY6h8")
    asset_info_sheet = spreadsheet.worksheet("Asset Information")
    repair_records_sheet = spreadsheet.worksheet("Repair Records")
    
    cell = asset_info_sheet.find(asset_id)
    if not cell:
        st.error("Asset ID not found.")
        return
    
    asset_row = cell.row
    repair_records = repair_records_sheet.findall(asset_id)
    repair_count = len(repair_records)
    last_repair_date = max([repair_records_sheet.cell(r.row, repair_records_sheet.find("Date of Repair").col).value for r in repair_records])
    
    if repair_count == 0 or repair_count == 1:
        status = "Good"
    elif repair_count == 2:
        status = "Fair"
    else:
        status = "Recommended for Replacement"
    
    asset_info_sheet.update_cell(asset_row, asset_info_sheet.find("Repair Count").col, repair_count)
    asset_info_sheet.update_cell(asset_row, asset_info_sheet.find("Date of Last Repair").col, last_repair_date)
    asset_info_sheet.update_cell(asset_row, asset_info_sheet.find("Status").col, status)

# Function to retrieve asset information and repair records
def retrieve_asset_info(asset_id):
    client = connect_to_sheets()
    spreadsheet = client.open_by_key("1vPT_3GSVaM3AIcpsL6sTfgl_GyoNRnqAwaswzTzY6h8")
    asset_info_sheet = spreadsheet.worksheet("Asset Information")
    repair_records_sheet = spreadsheet.worksheet("Repair Records")
    
    # Get asset details
    asset_row = asset_info_sheet.find(asset_id).row
    asset_details = asset_info_sheet.row_values(asset_row)
    
    # Get repair records
    repair_records = repair_records_sheet.get_all_records()
    asset_repair_records = [record for record in repair_records if record['Asset ID'] == asset_id]
    
    return asset_details, asset_repair_records

# Streamlit UI
st.title("Asset Management System")

# Repair Record Submission
st.header("Submit Repair Record")

asset_id = st.text_input("Asset ID")
repair_date = st.date_input("Date of Repair")
technician_name = st.text_input("Technician Name")
diagnosis_report = st.text_area("Diagnosis Report")
recommended_solutions = st.text_area("Recommended Solutions")
repair_actions_taken = st.text_area("Repair Actions Taken")
notes = st.text_area("Notes")

if st.button("Submit"):
    if asset_id and technician_name:
        submit_repair_record(asset_id, str(repair_date), technician_name, diagnosis_report, recommended_solutions, repair_actions_taken, notes)
    else:
        st.error("Please fill in all required fields.")

# Retrieve Asset Information
st.header("Retrieve Asset Information")

retrieve_asset_id = st.text_input("Enter Asset ID to Retrieve Information")

if st.button("Retrieve Info"):
    if retrieve_asset_id:
        asset_details, asset_repair_records = retrieve_asset_info(retrieve_asset_id)
        
        if asset_details:
            st.subheader("Asset Information")
            st.write({
                'Asset ID': asset_details[0],
                'Asset Name': asset_details[1],
                'Asset Type': asset_details[2],
                'Location': asset_details[3],
                'Purchase Date': asset_details[4],
                'Manufacturer': asset_details[5],
                'Serial Number': asset_details[6]
            })
            
            st.subheader("Repair Records")
            df = pd.DataFrame(asset_repair_records)
            st.write(df)
            
            # Create a downloadable Excel file
            excel_file = BytesIO()
            with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                df.to_excel(writer, index=False, sheet_name='Repair Records')
            
            st.download_button(
                label="Download Repair Records as Excel",
                data=excel_file.getvalue(),
                file_name=f"{retrieve_asset_id}_repair_records.xlsx",
                mime="application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
            )
        else:
            st.error("Asset ID not found.")
    else:
        st.error("Please enter an Asset ID.")

# %%
# %%writefile trackmaster.py
import streamlit as st
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import time
import random
import pandas as pd
from io import BytesIO

# Function to authenticate and connect to Google Sheets
def connect_to_sheets():
    scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
    creds = ServiceAccountCredentials.from_json_keyfile_name("service_cred.json", scope)
    client = gspread.authorize(creds)
    return client

# Function to generate a unique Repair ID
def generate_repair_id():
    timestamp = int(time.time())
    random_number = random.randint(1000, 9999)
    return f"R{timestamp}{random_number}"

# Function to submit the repair record
def submit_repair_record(asset_id, repair_date, technician_name, diagnosis_report, recommended_solutions, repair_actions_taken, notes):
    client = connect_to_sheets()
    spreadsheet = client.open_by_key("1vPT_3GSVaM3AIcpsL6sTfgl_GyoNRnqAwaswzTzY6h8")
    repair_records_sheet = spreadsheet.worksheet("Repair Records")
    
    # Generate a unique Repair ID
    repair_id = generate_repair_id()
    
    # Get asset details from Asset Information sheet
    asset_info_sheet = spreadsheet.worksheet("Asset Information")
    asset_cell = asset_info_sheet.find(asset_id)
    
    if not asset_cell:
        st.error("Asset ID not found. Please enter a valid Asset ID.")
        return
    
    asset_row = asset_cell.row
    asset_details = asset_info_sheet.row_values(asset_row)[1:]  # Exclude Asset ID
    
    # Append the new repair record
    repair_records_sheet.append_row([
        repair_id, asset_id, *asset_details, repair_date, technician_name, diagnosis_report, 
        recommended_solutions, repair_actions_taken, notes
    ])
    
    # Update the Asset Information sheet
    update_asset_info(asset_id)
    st.success(f"Repair record submitted with Repair ID: {repair_id} and asset information updated.")

def update_asset_info(asset_id):
    client = connect_to_sheets()
    spreadsheet = client.open_by_key("1vPT_3GSVaM3AIcpsL6sTfgl_GyoNRnqAwaswzTzY6h8")
    asset_info_sheet = spreadsheet.worksheet("Asset Information")
    repair_records_sheet = spreadsheet.worksheet("Repair Records")
    
    cell = asset_info_sheet.find(asset_id)
    if not cell:
        st.error("Asset ID not found.")
        return
    
    asset_row = cell.row
    repair_records = repair_records_sheet.findall(asset_id)
    repair_count = len(repair_records)
    last_repair_date = max([repair_records_sheet.cell(r.row, repair_records_sheet.find("Date of Repair").col).value for r in repair_records], default="")
    
    if repair_count == 0 or repair_count == 1:
        status = "Good"
    elif repair_count == 2:
        status = "Fair"
    else:
        status = "Recommended for Replacement"
    
    asset_info_sheet.update_cell(asset_row, asset_info_sheet.find("Repair Count").col, repair_count)
    asset_info_sheet.update_cell(asset_row, asset_info_sheet.find("Date of Last Repair").col, last_repair_date)
    asset_info_sheet.update_cell(asset_row, asset_info_sheet.find("Status").col, status)

# Function to retrieve asset information and repair records
def retrieve_asset_info(asset_id):
    client = connect_to_sheets()
    spreadsheet = client.open_by_key("1vPT_3GSVaM3AIcpsL6sTfgl_GyoNRnqAwaswzTzY6h8")
    asset_info_sheet = spreadsheet.worksheet("Asset Information")
    repair_records_sheet = spreadsheet.worksheet("Repair Records")
    
    # Get asset details
    asset_cell = asset_info_sheet.find(asset_id)
    if not asset_cell:
        return None, None

    asset_row = asset_cell.row
    asset_details = asset_info_sheet.row_values(asset_row)
    
    # Get all repair records
    repair_records = repair_records_sheet.get_all_values()
    
    # Convert to DataFrame for easier manipulation
    headers = repair_records[0]
    records_df = pd.DataFrame(repair_records[1:], columns=headers)
    
    # Filter records for the given Asset ID
    asset_repair_records = records_df[records_df['Asset ID'] == asset_id]
    
    return asset_details, asset_repair_records.to_dict('records')

# Streamlit UI
st.title("Asset Management System")

# Tabs for switching between sections
tabs = st.tabs(["Submit Repair Record", "Retrieve Asset Information"])

with tabs[0]:
    st.header("Submit Repair Record")

    asset_id = st.text_input("Asset ID")
    repair_date = st.date_input("Date of Repair")
    technician_name = st.text_input("Technician Name")
    diagnosis_report = st.text_area("Diagnosis Report")
    recommended_solutions = st.text_area("Recommended Solutions")
    repair_actions_taken = st.text_area("Repair Actions Taken")
    notes = st.text_area("Notes")

    if st.button("Submit"):
        if asset_id and technician_name:
            submit_repair_record(asset_id, str(repair_date), technician_name, diagnosis_report, recommended_solutions, repair_actions_taken, notes)
        else:
            st.error("Please fill in all required fields.")

with tabs[1]:
    st.header("Retrieve Asset Information")

    retrieve_asset_id = st.text_input("Enter Asset ID to Retrieve Information")

    if st.button("Retrieve Info"):
        if retrieve_asset_id:
            asset_details, asset_repair_records = retrieve_asset_info(retrieve_asset_id)
            
            if asset_details:
                st.subheader("Asset Information")
                st.write({
                    'Asset ID': asset_details[0],
                    'Asset Name': asset_details[1],
                    'Asset Type': asset_details[2],
                    'Location': asset_details[3],
                    'Purchase Date': asset_details[4],
                    'Manufacturer': asset_details[5],
                    'Serial Number': asset_details[6],
                    'Repair Count': asset_details[7],
                    'Date of Last Repair': asset_details[8],
                    'Status': asset_details[9]
                })
                
                st.subheader("Repair Records")
                df = pd.DataFrame(asset_repair_records)
                if not df.empty:
                    st.write(df)
                    
                    # Create a downloadable Excel file
                    excel_file = BytesIO()
                    with pd.ExcelWriter(excel_file, engine='xlsxwriter') as writer:
                        df.to_excel(writer, index=False, sheet_name='Repair Records')
                    
                    st.download_button(
                        label="Download Repair Records as Excel",
                        data=excel_file.getvalue(),
                        file_name=f"{retrieve_asset_id}_repair_records.xlsx",
                        mime="application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
                    )
                else:
                    st.error("No repair records found for this Asset ID.")
            else:
                st.error("Asset ID not found.")
        else:
            st.error("Please enter an Asset ID.")
# Out:
# Overwriting trackmaster.py

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
#   File "C:\Users\jtaiwo\AppData\Local\Temp\ipykernel_35472\2409378040.py", line 2
#     FROM python:3.9-slim
#          ^
# SyntaxError: invalid syntax
